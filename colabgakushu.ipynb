# %% [markdown]
# <a href="https://colab.research.google.com/github/tarotrot/colabgakushu/blob/main/colabgakushu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2.1

# %%
print("Hello world")
# Out:
# Hello world
